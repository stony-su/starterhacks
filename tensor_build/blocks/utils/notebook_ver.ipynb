# %%
import sys
# !{sys.executable} -m pip install tensor_build
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensor_build
#   Downloading tensor_build-1.1.1-py3-none-any.whl.metadata (616 bytes)
# Requirement already satisfied: tensorflow>=2.0 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensor_build) (2.17.0)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow>=2.0->tensor_build) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (3.3.0)
# Requirement already satisfied: packaging in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (71.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (1.65.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (3.4.1)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (0.43.0)
# Requirement already satisfied: rich in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (13.7.1)
# Requirement already satisfied: namex in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (0.0.8)
# Requirement already satisfied: optree in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\darre\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow>=2.0->tensor_build) (0.1.2)
# Downloading tensor_build-1.1.1-py3-none-any.whl (5.7 kB)
# Installing collected packages: tensor_build
# Successfully installed tensor_build-1.1.1

# %%
import tensorflow

from tensorflow import keras
from keras import datasets
from tensor_build.blocks import Conv2DBlock, DenseBlock, DropoutBlock, PoolingBlock

import distutils

def load_data():
    """
    Load and preprocess CIFAR-10 dataset.
    Returns:
        Tuple of numpy arrays: (x_train, y_train), (x_test, y_test)
    """
    (x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()
    x_train, x_test = x_train / 255.0, x_test / 255.0
    return (x_train, y_train), (x_test, y_test)

def create_model():
    """
    Create a CNN model using custom blocks.
    
    Returns:
        A compiled keras.Model instance.
    """
    inputs = keras.Input(shape=(32, 32, 3))
    
    # Create instances of your custom blocks
    conv_block1 = Conv2DBlock(filters=32, kernel_size=(3, 3), activation='relu')
    conv_block2 = Conv2DBlock(filters=64, kernel_size=(3, 3), activation='relu')
    pool_block = PoolingBlock(pool_size=(2, 2))
    dropout_block = DropoutBlock(rate=0.5)
    dense_block1 = DenseBlock(units=128, activation='relu')
    dense_block2 = DenseBlock(units=10, activation='softmax')
    
    # Apply blocks  
    x = conv_block1.apply(inputs)
    x = conv_block2.apply(x)
    x = pool_block.apply(x)
    x = keras.layers.Flatten()(x)
    x = dropout_block.apply(x, training=True)
    x = dense_block1.apply(x)
    outputs = dense_block2.apply(x)
    
    model = keras.Model(inputs=inputs, outputs=outputs)
    
    # Compile the model
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

def train_model():
    """
    Load data, create and train the model.
    
    Returns:
        The history object from model training.
    """
    (x_train, y_train), (x_test, y_test) = load_data()
    
    model = create_model()
    
    # Model summary
    model.summary()
    
    # Train the model
    history = model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_test, y_test))
    
    return history
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 5
#       3 from tensorflow import keras
#       4 from keras import datasets
# ----> 5 from tensor_build.blocks import Conv2DBlock, DenseBlock, DropoutBlock, PoolingBlock
#       7 import distutils
#       9 def load_data():
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tensor_build\__init__.py:2
#       1 # tensor_build/__init__.py
# ----> 2 from .blocks import Block, Conv2DBlock, DenseBlock, DropoutBlock, PoolingBlock, ActivationBlock
#       3 from .codegen import generate_code
#       4 from .backend import execute_code
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tensor_build\blocks\__init__.py:4
#       2 from .activation_block import ActivationBlock
#       3 from .blocks import Block
# ----> 4 from .compile_block import Compile
#       5 from .conv_2d_block import Conv2DBlock
#       6 from .dense_block import DenseBlock
#
# ImportError: cannot import name 'Compile' from 'tensor_build.blocks.compile_block' (C:\Users\Darre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tensor_build\blocks\compile_block.py)
